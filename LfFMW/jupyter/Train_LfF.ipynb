# %%
import os
os.chdir('..')

# %%
from data.attr_dataset import AttributeDataset_bffhq
from module.loss import GeneralizedCELoss,EMA,MultiDimAverageMeter
from module.models import dic_models
from module.models2 import dic_models_2
from data.util import get_dataset, IdxDataset, ZippedDataset, get_dataset_bffhq
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from collections import Counter
from torch.utils.data import DataLoader, Dataset
from tqdm import tqdm
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import argparse
from torch.optim.lr_scheduler import MultiStepLR
import random
from numpy.random import RandomState

def set_seed(seed: int) -> RandomState:
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False # set to false for reproducibility, True to boost performance
    torch.manual_seed(seed)
    np.random.seed(seed)
    torch.cuda.manual_seed(seed)
    random.seed(seed)
    random_state = random.getstate()
    os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"
    return random_state


dataset_in = input("The dataset is: ")
model_in = input("The model is: ")
train_samples = int(input("The number of training samples is: "))
bias_ratio = float(input("The bias ratio is: "))
seed = int(input("The seed is: "))

set_seed(seed)

target_attr_idx = 0
bias_attr_idx = 1

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def write_to_file(filename, text):
    with open(filename, 'a') as f:
        f.write(text)
        f.write('\n')

# %%
def evaluate_accuracy(mw_model, test_loader):
  mw_model.eval()
  mw_correct = 0
  with torch.no_grad():
    for _, data, target in test_loader:
        data = data.to(device)
        target = target[:,target_attr_idx]
        target = target.to(device)

        mw_outputs  = mw_model(data)
        mw_pred = mw_outputs.data.max(1, keepdim=True)[1]

        mw_correct += mw_pred.eq(target.data.view_as(mw_pred)).sum().item()
  mw_accuracy = 100.*(torch.true_divide(mw_correct,len(test_loader.dataset))).item()
  mw_model.train()
  return mw_accuracy

# %%
train_dataset = get_dataset(
        dataset_in,
        data_dir='/home/user/datasets/debias',
        dataset_split="train",
        transform_split="train",
    )
test_dataset = get_dataset(
        dataset_in,
        data_dir='/home/user/datasets/debias',
        dataset_split="eval",
        transform_split="eval",
    )
valid_dataset = get_dataset(
        dataset_in,
        data_dir='/home/user/datasets/debias',
        dataset_split="train",
        transform_split="train",
)

# %%
indices_train_biased = train_dataset.attr[:,0] == train_dataset.attr[:,1]

indices_train_biased = indices_train_biased.nonzero().squeeze()

nums_train_biased = np.random.choice(indices_train_biased, int(train_samples - bias_ratio * train_samples) , replace=False)


indices_train_unbiased = train_dataset.attr[:,0] != train_dataset.attr[:,1]

indices_train_unbiased = indices_train_unbiased.nonzero().squeeze()

nums_train_unbiased = np.random.choice(indices_train_unbiased, int(bias_ratio * train_samples) , replace=False)

nums_train = np.concatenate((nums_train_biased, nums_train_unbiased))


nums_valid_unbiased = []

while len(nums_valid_unbiased) < 1000:
    i = np.random.randint(0, len(valid_dataset))
    if valid_dataset.attr[i,0] != valid_dataset.attr[i,1] and i not in nums_train:
        nums_valid_unbiased.append(i)

nums_valid_unbiased = np.array(nums_valid_unbiased)

train_dataset.attr = train_dataset.attr[nums_train]
train_dataset.data = train_dataset.data[nums_train]
train_dataset.__len__ = train_samples
train_dataset.query_attr = train_dataset.attr[:, torch.arange(2)]


valid_dataset.attr = valid_dataset.attr[nums_valid_unbiased]
valid_dataset.data = valid_dataset.data[nums_valid_unbiased]
valid_dataset.__len__ = 1000
valid_dataset.query_attr = valid_dataset.attr[:, torch.arange(2)]

print("[Size of the Dataset]["+str(len(train_dataset))+"]")
print("[Conflicting Samples in Training Data]["+str(len(train_dataset.attr[train_dataset.attr[:,0] != train_dataset.attr[:,1]]))+"]")
print("[Conflicting Samples in Validation Data]["+str(len(valid_dataset.attr[valid_dataset.attr[:,0] != valid_dataset.attr[:,1]]))+"]")

train_target_attr = train_dataset.attr[:, target_attr_idx]
train_bias_attr = train_dataset.attr[:, bias_attr_idx]

del indices_train_biased, indices_train_unbiased, nums_train_biased, nums_train_unbiased, nums_train, nums_valid_unbiased
# Out:
# [Size of the Dataset][2000]
# [Conflicting Samples in Training Data][40]
# [Conflicting Samples in Validation Data][1000]

# %%
attr_dims = []
attr_dims.append(torch.max(train_target_attr).item() + 1)
num_classes = attr_dims[0]

# %%
train_dataset = IdxDataset(train_dataset)
valid_dataset = IdxDataset(valid_dataset)    
test_dataset = IdxDataset(test_dataset)
 
train_loader = DataLoader(
        train_dataset,
        batch_size=250,
        shuffle=True,
        drop_last=True
    )

valid_loader = DataLoader(
        valid_dataset,
        batch_size=250,
        shuffle=False,
        drop_last=False
    )

test_loader = DataLoader(
        test_dataset,
        batch_size=250,
        shuffle=False,
        drop_last=False
    )

# %%
try:
    model_d = dic_models[model_in](num_classes).to(device)
    model_b = dic_models[model_in](num_classes).to(device)
except:
    model_d = dic_models_2[model_in](num_classes).to(device)
    model_b = dic_models_2[model_in](num_classes).to(device)

# %%
if 'MNIST' in dataset_in:
    optimizer_b = torch.optim.Adam(model_b.parameters(),lr= 0.002, weight_decay=0.0)
    optimizer_d = torch.optim.Adam(model_d.parameters(),lr= 0.002, weight_decay=0.0)
    schedulerd = MultiStepLR(optimizer_d, milestones=[300], gamma=0.5)
    schedulerb = MultiStepLR(optimizer_b, milestones=[300], gamma=0.5)
else:
    optimizer_b = torch.optim.SGD(model_b.parameters(),lr= 0.1, weight_decay=5e-4, momentum = 0.9, nesterov = True)
    optimizer_d = torch.optim.SGD(model_d.parameters(),lr= 0.1, weight_decay=5e-4, momentum = 0.9, nesterov = True)
    schedulerd = MultiStepLR(optimizer_d, milestones=[150,225], gamma=0.1)
    schedulerb = MultiStepLR(optimizer_b, milestones=[150,225], gamma=0.1)

# %%
criterion = nn.CrossEntropyLoss(reduction='none')
bias_criterion = GeneralizedCELoss()

# %%
sample_loss_ema_b = EMA(torch.LongTensor(train_target_attr), alpha=0.7)
sample_loss_ema_d = EMA(torch.LongTensor(train_target_attr), alpha=0.7)

# %%
if 'CIFAR' in dataset_in:
    main_num_steps = 1
elif 'MNIST' in dataset_in:
    main_num_steps = 200

# %%
test_accuracy = -1.0
test_cheat = -1.0
test_accuracy_epoch = -1.0
valid_accuracy_best = -1.0

# %%
for step in range(1, main_num_steps+1):

    for ix, (index,data,attr) in enumerate(train_loader):

        data = data.to(device)
        attr = attr.to(device)

        label = attr[:, target_attr_idx]
        bias_label = attr[:, bias_attr_idx]

        logit_b = model_b(data)
        logit_d = model_d(data)


        loss_b = criterion(logit_b, label).cpu().detach()
        loss_d = criterion(logit_d, label).cpu().detach()
        
        loss_per_sample_b = loss_b
        loss_per_sample_d = loss_d
        
        # EMA sample loss
        sample_loss_ema_b.update(loss_b, index)
        sample_loss_ema_d.update(loss_d, index)
        
        # class-wise normalize
        loss_b = sample_loss_ema_b.parameter[index].clone().detach()
        loss_d = sample_loss_ema_d.parameter[index].clone().detach()
        
        label_cpu = label.cpu()
        
        for c in range(num_classes):
            class_index = np.where(label_cpu == c)[0]
            max_loss_b = sample_loss_ema_b.max_loss(c)
            max_loss_d = sample_loss_ema_d.max_loss(c)
            loss_b[class_index] /= max_loss_b
            loss_d[class_index] /= max_loss_d
   
        # re-weighting based on loss value / generalized CE for biased model
        loss_weight = loss_b / (loss_b + loss_d + 1e-8)

        loss_b_update = bias_criterion(logit_b, label)

        loss_d_update = criterion(logit_d, label) * loss_weight.to(device)

        loss = loss_b_update.mean() + loss_d_update.mean()

        optimizer_b.zero_grad()
        optimizer_d.zero_grad()
        loss.backward()
        optimizer_b.step()
        optimizer_d.step()
    
    schedulerb.step()
    schedulerd.step()

    train_accuracy_epoch = evaluate_accuracy(model_d, train_loader)
    prev_valid_accuracy = valid_accuracy_best
    valid_accuracy_epoch = evaluate_accuracy(model_d, valid_loader)
    valid_accuracy_best = max(valid_accuracy_best, valid_accuracy_epoch)

    print("[Epoch "+str(step)+"][Train Accuracy", round(train_accuracy_epoch,4),"][Validation Accuracy",round(valid_accuracy_epoch,4),"]")

    test_accuracy_epoch = evaluate_accuracy(model_d, test_loader)

    test_cheat = max(test_cheat, test_accuracy_epoch)

    print("[Test Accuracy cheat][%.4f]"%test_cheat)

    if valid_accuracy_best > prev_valid_accuracy:
        test_accuracy = test_accuracy_epoch

    print('[Best Test Accuracy]', test_accuracy)


write_to_file('results_text/results_Vanilla_LfF_'+str(dataset_in.split('-')[0])+'_'+str(train_samples)+'_'+str(bias_ratio)+'.txt','[Best Test Accuracy]'+str(test_accuracy)+"[Final Epoch Test Accuracy]"+str(test_accuracy_epoch)+ '[Best Cheat Test Accuracy]'+str(test_cheat))
# Out:
# [Epoch 1][Train Accuracy 28.6 ][Validation Accuracy 18.2 ]
# [Test Accuracy cheat][16.4500]
# [Best Test Accuracy] 16.449999809265137
# [Epoch 2][Train Accuracy 10.7 ][Validation Accuracy 9.6 ]
# [Test Accuracy cheat][16.4500]
# [Best Test Accuracy] 16.449999809265137
# [Epoch 3][Train Accuracy 10.7 ][Validation Accuracy 10.0 ]
# [Test Accuracy cheat][16.4500]
# [Best Test Accuracy] 16.449999809265137
# [Epoch 4][Train Accuracy 37.35 ][Validation Accuracy 19.9 ]
# [Test Accuracy cheat][19.2100]
# [Best Test Accuracy] 19.210000336170197
# [Epoch 5][Train Accuracy 65.95 ][Validation Accuracy 35.4 ]
# [Test Accuracy cheat][35.0900]
# [Best Test Accuracy] 35.08999943733215
# [Epoch 6][Train Accuracy 91.25 ][Validation Accuracy 43.5 ]
# [Test Accuracy cheat][40.9900]
# [Best Test Accuracy] 40.99000096321106
# [Epoch 7][Train Accuracy 99.2 ][Validation Accuracy 47.9 ]
# [Test Accuracy cheat][42.9700]
# [Best Test Accuracy] 42.969998717308044
# [Epoch 8][Train Accuracy 99.7 ][Validation Accuracy 50.3 ]
# [Test Accuracy cheat][42.9700]
# [Best Test Accuracy] 42.59999990463257
# [Epoch 9][Train Accuracy 99.85 ][Validation Accuracy 50.1 ]
# [Test Accuracy cheat][43.0100]
# [Best Test Accuracy] 42.59999990463257
# [Epoch 10][Train Accuracy 99.95 ][Validation Accuracy 50.4 ]
# [Test Accuracy cheat][43.0300]
# [Best Test Accuracy] 43.02999973297119
# [Epoch 11][Train Accuracy 100.0 ][Validation Accuracy 50.9 ]
# [Test Accuracy cheat][43.1000]
# [Best Test Accuracy] 43.09999942779541
# [Epoch 12][Train Accuracy 100.0 ][Validation Accuracy 51.0 ]
# [Test Accuracy cheat][43.1600]
# [Best Test Accuracy] 43.16000044345856
# [Epoch 13][Train Accuracy 100.0 ][Validation Accuracy 51.3 ]
# [Test Accuracy cheat][43.1600]
# [Best Test Accuracy] 43.1300014257431
# [Epoch 14][Train Accuracy 100.0 ][Validation Accuracy 52.0 ]
# [Test Accuracy cheat][43.1900]
# [Best Test Accuracy] 43.18999946117401
# [Epoch 15][Train Accuracy 100.0 ][Validation Accuracy 52.0 ]
# [Test Accuracy cheat][43.3100]
# [Best Test Accuracy] 43.18999946117401
# [Epoch 16][Train Accuracy 100.0 ][Validation Accuracy 53.1 ]
# [Test Accuracy cheat][43.3300]
# [Best Test Accuracy] 43.32999885082245
# [Epoch 17][Train Accuracy 99.95 ][Validation Accuracy 53.0 ]
# [Test Accuracy cheat][43.5800]
# [Best Test Accuracy] 43.32999885082245
# [Epoch 18][Train Accuracy 99.95 ][Validation Accuracy 53.1 ]
# [Test Accuracy cheat][43.7300]
# [Best Test Accuracy] 43.32999885082245
# [Epoch 19][Train Accuracy 99.9 ][Validation Accuracy 53.0 ]
# [Test Accuracy cheat][43.9200]
# [Best Test Accuracy] 43.32999885082245
# [Epoch 20][Train Accuracy 99.9 ][Validation Accuracy 53.1 ]
# [Test Accuracy cheat][44.1700]
# [Best Test Accuracy] 43.32999885082245
# [Epoch 21][Train Accuracy 99.9 ][Validation Accuracy 53.3 ]
# [Test Accuracy cheat][44.2500]
# [Best Test Accuracy] 44.24999952316284
# [Epoch 22][Train Accuracy 99.9 ][Validation Accuracy 52.9 ]
# [Test Accuracy cheat][44.2500]
# [Best Test Accuracy] 44.24999952316284
# [Epoch 23][Train Accuracy 99.9 ][Validation Accuracy 52.7 ]
# [Test Accuracy cheat][44.2500]
# [Best Test Accuracy] 44.24999952316284
# [Epoch 24][Train Accuracy 99.95 ][Validation Accuracy 53.0 ]
# [Test Accuracy cheat][44.2600]
# [Best Test Accuracy] 44.24999952316284
# [Epoch 25][Train Accuracy 99.9 ][Validation Accuracy 53.0 ]
# [Test Accuracy cheat][44.4700]
# [Best Test Accuracy] 44.24999952316284
# [Epoch 26][Train Accuracy 99.9 ][Validation Accuracy 53.5 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.51000094413757
# [Epoch 27][Train Accuracy 99.9 ][Validation Accuracy 53.9 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 28][Train Accuracy 99.95 ][Validation Accuracy 53.7 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 29][Train Accuracy 99.9 ][Validation Accuracy 53.7 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 30][Train Accuracy 99.9 ][Validation Accuracy 53.4 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 31][Train Accuracy 99.95 ][Validation Accuracy 53.8 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 32][Train Accuracy 99.95 ][Validation Accuracy 53.9 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 33][Train Accuracy 99.95 ][Validation Accuracy 53.6 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 34][Train Accuracy 99.95 ][Validation Accuracy 53.2 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 35][Train Accuracy 99.95 ][Validation Accuracy 52.6 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 36][Train Accuracy 100.0 ][Validation Accuracy 52.6 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 37][Train Accuracy 100.0 ][Validation Accuracy 52.3 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 38][Train Accuracy 100.0 ][Validation Accuracy 52.6 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 39][Train Accuracy 100.0 ][Validation Accuracy 52.7 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 40][Train Accuracy 100.0 ][Validation Accuracy 52.6 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 41][Train Accuracy 100.0 ][Validation Accuracy 52.6 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 42][Train Accuracy 100.0 ][Validation Accuracy 52.6 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 43][Train Accuracy 100.0 ][Validation Accuracy 52.1 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 44][Train Accuracy 100.0 ][Validation Accuracy 52.0 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 45][Train Accuracy 100.0 ][Validation Accuracy 52.1 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 46][Train Accuracy 100.0 ][Validation Accuracy 52.0 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 47][Train Accuracy 100.0 ][Validation Accuracy 52.1 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 48][Train Accuracy 100.0 ][Validation Accuracy 52.2 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 49][Train Accuracy 100.0 ][Validation Accuracy 52.1 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 50][Train Accuracy 100.0 ][Validation Accuracy 52.2 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 51][Train Accuracy 100.0 ][Validation Accuracy 52.2 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 52][Train Accuracy 100.0 ][Validation Accuracy 52.2 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 53][Train Accuracy 100.0 ][Validation Accuracy 52.3 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 54][Train Accuracy 100.0 ][Validation Accuracy 52.2 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 55][Train Accuracy 100.0 ][Validation Accuracy 52.5 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 56][Train Accuracy 100.0 ][Validation Accuracy 52.2 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 57][Train Accuracy 100.0 ][Validation Accuracy 52.2 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 58][Train Accuracy 100.0 ][Validation Accuracy 52.4 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 59][Train Accuracy 100.0 ][Validation Accuracy 52.7 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 60][Train Accuracy 100.0 ][Validation Accuracy 52.6 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 61][Train Accuracy 100.0 ][Validation Accuracy 52.8 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 62][Train Accuracy 100.0 ][Validation Accuracy 52.7 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 63][Train Accuracy 100.0 ][Validation Accuracy 52.5 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 64][Train Accuracy 100.0 ][Validation Accuracy 52.7 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 65][Train Accuracy 100.0 ][Validation Accuracy 52.4 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 66][Train Accuracy 99.95 ][Validation Accuracy 52.7 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 67][Train Accuracy 99.95 ][Validation Accuracy 52.5 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 68][Train Accuracy 99.95 ][Validation Accuracy 52.7 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 69][Train Accuracy 100.0 ][Validation Accuracy 52.9 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 70][Train Accuracy 100.0 ][Validation Accuracy 52.2 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 71][Train Accuracy 99.95 ][Validation Accuracy 52.2 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 72][Train Accuracy 99.95 ][Validation Accuracy 52.5 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 73][Train Accuracy 99.95 ][Validation Accuracy 52.3 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 74][Train Accuracy 99.95 ][Validation Accuracy 52.9 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 75][Train Accuracy 99.95 ][Validation Accuracy 52.8 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 76][Train Accuracy 99.95 ][Validation Accuracy 53.0 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 77][Train Accuracy 99.95 ][Validation Accuracy 53.1 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 78][Train Accuracy 99.95 ][Validation Accuracy 53.2 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 79][Train Accuracy 99.95 ][Validation Accuracy 52.9 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 80][Train Accuracy 99.95 ][Validation Accuracy 53.4 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 81][Train Accuracy 99.95 ][Validation Accuracy 53.5 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 82][Train Accuracy 99.95 ][Validation Accuracy 53.1 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 83][Train Accuracy 99.95 ][Validation Accuracy 53.2 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 84][Train Accuracy 99.95 ][Validation Accuracy 53.1 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 85][Train Accuracy 100.0 ][Validation Accuracy 53.3 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 86][Train Accuracy 100.0 ][Validation Accuracy 52.9 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 87][Train Accuracy 100.0 ][Validation Accuracy 52.8 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 88][Train Accuracy 100.0 ][Validation Accuracy 52.7 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 89][Train Accuracy 100.0 ][Validation Accuracy 52.5 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 90][Train Accuracy 100.0 ][Validation Accuracy 52.9 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 91][Train Accuracy 100.0 ][Validation Accuracy 52.6 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 92][Train Accuracy 100.0 ][Validation Accuracy 52.6 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 93][Train Accuracy 100.0 ][Validation Accuracy 52.5 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 94][Train Accuracy 100.0 ][Validation Accuracy 52.3 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 95][Train Accuracy 100.0 ][Validation Accuracy 52.5 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 96][Train Accuracy 100.0 ][Validation Accuracy 52.2 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 97][Train Accuracy 100.0 ][Validation Accuracy 52.2 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 98][Train Accuracy 100.0 ][Validation Accuracy 52.2 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 99][Train Accuracy 100.0 ][Validation Accuracy 52.1 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 100][Train Accuracy 100.0 ][Validation Accuracy 52.1 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 101][Train Accuracy 100.0 ][Validation Accuracy 52.0 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 102][Train Accuracy 100.0 ][Validation Accuracy 52.2 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 103][Train Accuracy 100.0 ][Validation Accuracy 51.9 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 104][Train Accuracy 100.0 ][Validation Accuracy 51.8 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 105][Train Accuracy 100.0 ][Validation Accuracy 51.7 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 106][Train Accuracy 100.0 ][Validation Accuracy 51.6 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 107][Train Accuracy 100.0 ][Validation Accuracy 51.7 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 108][Train Accuracy 100.0 ][Validation Accuracy 51.8 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 109][Train Accuracy 100.0 ][Validation Accuracy 51.2 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 110][Train Accuracy 100.0 ][Validation Accuracy 50.5 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 111][Train Accuracy 100.0 ][Validation Accuracy 50.7 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 112][Train Accuracy 100.0 ][Validation Accuracy 50.6 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 113][Train Accuracy 100.0 ][Validation Accuracy 50.0 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 114][Train Accuracy 100.0 ][Validation Accuracy 50.0 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 115][Train Accuracy 100.0 ][Validation Accuracy 49.9 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 116][Train Accuracy 100.0 ][Validation Accuracy 49.4 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 117][Train Accuracy 100.0 ][Validation Accuracy 49.5 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 118][Train Accuracy 100.0 ][Validation Accuracy 49.6 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 119][Train Accuracy 100.0 ][Validation Accuracy 50.1 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 120][Train Accuracy 100.0 ][Validation Accuracy 50.7 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 121][Train Accuracy 100.0 ][Validation Accuracy 50.6 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 122][Train Accuracy 100.0 ][Validation Accuracy 50.9 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 123][Train Accuracy 100.0 ][Validation Accuracy 51.2 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 124][Train Accuracy 100.0 ][Validation Accuracy 50.9 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 125][Train Accuracy 100.0 ][Validation Accuracy 51.3 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 126][Train Accuracy 100.0 ][Validation Accuracy 51.4 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 127][Train Accuracy 100.0 ][Validation Accuracy 51.3 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 128][Train Accuracy 100.0 ][Validation Accuracy 50.9 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 129][Train Accuracy 100.0 ][Validation Accuracy 51.3 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 130][Train Accuracy 100.0 ][Validation Accuracy 51.1 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 131][Train Accuracy 100.0 ][Validation Accuracy 50.9 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 132][Train Accuracy 100.0 ][Validation Accuracy 50.7 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 133][Train Accuracy 100.0 ][Validation Accuracy 50.9 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 134][Train Accuracy 100.0 ][Validation Accuracy 51.1 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 135][Train Accuracy 100.0 ][Validation Accuracy 51.0 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 136][Train Accuracy 100.0 ][Validation Accuracy 50.8 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 137][Train Accuracy 100.0 ][Validation Accuracy 50.8 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 138][Train Accuracy 100.0 ][Validation Accuracy 51.0 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 139][Train Accuracy 100.0 ][Validation Accuracy 51.0 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 140][Train Accuracy 100.0 ][Validation Accuracy 51.0 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 141][Train Accuracy 100.0 ][Validation Accuracy 51.1 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 142][Train Accuracy 100.0 ][Validation Accuracy 50.7 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 143][Train Accuracy 100.0 ][Validation Accuracy 50.8 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 144][Train Accuracy 100.0 ][Validation Accuracy 50.9 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 145][Train Accuracy 100.0 ][Validation Accuracy 50.9 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 146][Train Accuracy 100.0 ][Validation Accuracy 50.8 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 147][Train Accuracy 100.0 ][Validation Accuracy 50.7 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 148][Train Accuracy 100.0 ][Validation Accuracy 50.6 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 149][Train Accuracy 100.0 ][Validation Accuracy 51.3 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 150][Train Accuracy 100.0 ][Validation Accuracy 51.1 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 151][Train Accuracy 100.0 ][Validation Accuracy 51.4 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 152][Train Accuracy 100.0 ][Validation Accuracy 51.1 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 153][Train Accuracy 100.0 ][Validation Accuracy 51.3 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 154][Train Accuracy 100.0 ][Validation Accuracy 51.2 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 155][Train Accuracy 100.0 ][Validation Accuracy 51.2 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 156][Train Accuracy 100.0 ][Validation Accuracy 51.2 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 157][Train Accuracy 100.0 ][Validation Accuracy 51.5 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 158][Train Accuracy 100.0 ][Validation Accuracy 51.5 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 159][Train Accuracy 100.0 ][Validation Accuracy 51.4 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 160][Train Accuracy 100.0 ][Validation Accuracy 51.5 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 161][Train Accuracy 100.0 ][Validation Accuracy 51.4 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 162][Train Accuracy 100.0 ][Validation Accuracy 51.3 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 163][Train Accuracy 100.0 ][Validation Accuracy 51.3 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 164][Train Accuracy 100.0 ][Validation Accuracy 51.3 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 165][Train Accuracy 100.0 ][Validation Accuracy 51.1 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 166][Train Accuracy 100.0 ][Validation Accuracy 51.5 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 167][Train Accuracy 100.0 ][Validation Accuracy 51.3 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 168][Train Accuracy 100.0 ][Validation Accuracy 51.4 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 169][Train Accuracy 100.0 ][Validation Accuracy 51.4 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 170][Train Accuracy 100.0 ][Validation Accuracy 51.4 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 171][Train Accuracy 100.0 ][Validation Accuracy 51.2 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 172][Train Accuracy 100.0 ][Validation Accuracy 51.4 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 173][Train Accuracy 100.0 ][Validation Accuracy 51.3 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 174][Train Accuracy 100.0 ][Validation Accuracy 51.0 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 175][Train Accuracy 100.0 ][Validation Accuracy 51.2 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 176][Train Accuracy 100.0 ][Validation Accuracy 50.9 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 177][Train Accuracy 100.0 ][Validation Accuracy 51.2 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 178][Train Accuracy 100.0 ][Validation Accuracy 51.2 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 179][Train Accuracy 100.0 ][Validation Accuracy 51.1 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 180][Train Accuracy 100.0 ][Validation Accuracy 51.1 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 181][Train Accuracy 100.0 ][Validation Accuracy 51.5 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 182][Train Accuracy 100.0 ][Validation Accuracy 51.2 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 183][Train Accuracy 100.0 ][Validation Accuracy 50.8 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 184][Train Accuracy 100.0 ][Validation Accuracy 51.1 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 185][Train Accuracy 100.0 ][Validation Accuracy 50.9 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 186][Train Accuracy 100.0 ][Validation Accuracy 51.0 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 187][Train Accuracy 100.0 ][Validation Accuracy 50.9 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 188][Train Accuracy 100.0 ][Validation Accuracy 50.7 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 189][Train Accuracy 100.0 ][Validation Accuracy 51.0 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 190][Train Accuracy 100.0 ][Validation Accuracy 51.2 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 191][Train Accuracy 100.0 ][Validation Accuracy 50.9 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 192][Train Accuracy 100.0 ][Validation Accuracy 51.0 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 193][Train Accuracy 100.0 ][Validation Accuracy 50.8 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 194][Train Accuracy 100.0 ][Validation Accuracy 50.6 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 195][Train Accuracy 100.0 ][Validation Accuracy 51.0 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 196][Train Accuracy 100.0 ][Validation Accuracy 50.7 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 197][Train Accuracy 100.0 ][Validation Accuracy 50.8 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 198][Train Accuracy 100.0 ][Validation Accuracy 50.7 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 199][Train Accuracy 100.0 ][Validation Accuracy 50.8 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
# [Epoch 200][Train Accuracy 100.0 ][Validation Accuracy 50.7 ]
# [Test Accuracy cheat][44.5100]
# [Best Test Accuracy] 44.47999894618988
