# %%
import os
os.chdir('..')

# %%
from data.attr_dataset import AttributeDataset_bffhq
from module.loss import GeneralizedCELoss,EMA,MultiDimAverageMeter
from module.models import dic_models
from module.models2 import dic_models_2
from data.util import get_dataset, IdxDataset, ZippedDataset, get_dataset_bffhq
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from collections import Counter
from torch.utils.data import DataLoader, Dataset
from tqdm import tqdm
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import argparse
from torch.optim.lr_scheduler import MultiStepLR
import random
from numpy.random import RandomState

def set_seed(seed: int) -> RandomState:
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False # set to false for reproducibility, True to boost performance
    torch.manual_seed(seed)
    np.random.seed(seed)
    torch.cuda.manual_seed(seed)
    random.seed(seed)
    random_state = random.getstate()
    os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"
    return random_state


dataset_in = input("The dataset is: ")
model_in = input("The model is: ")
train_samples = int(input("The number of training samples is: "))
bias_ratio = float(input("The bias ratio is: "))
seed = int(input("The seed is: "))

set_seed(seed)

target_attr_idx = 0
bias_attr_idx = 1

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def write_to_file(filename, text):
    with open(filename, 'a') as f:
        f.write(text)
        f.write('\n')

# %%
def evaluate_accuracy(mw_model, test_loader, memory_loader):
  mw_model.eval()
  mw_correct = 0
  mem_iter = iter(memory_loader)
  with torch.no_grad():
    for _, data, target in test_loader:
        data = data.to(device)
        target = target[:,target_attr_idx]
        target = target.to(device)
        try:
            indexm,memory_input,_ = next(mem_iter)
        except:
            mem_iter = iter(memory_loader)
            indexm,memory_input,_ = next(mem_iter)
        memory_input = memory_input.to(device)

        mw_outputs = mw_model(data, memory_input)
        mw_pred = mw_outputs.data.max(1, keepdim=True)[1]

        mw_correct += mw_pred.eq(target.data.view_as(mw_pred)).sum().item()
  mw_accuracy = 100.*(torch.true_divide(mw_correct,len(test_loader.dataset))).item()
  mw_model.train()
  return mw_accuracy

# %%
train_dataset = get_dataset(
        dataset_in,
        data_dir='/home/user/datasets/debias',
        dataset_split="train",
        transform_split="train",
    )
test_dataset = get_dataset(
        dataset_in,
        data_dir='/home/user/datasets/debias',
        dataset_split="eval",
        transform_split="eval",
    )
valid_dataset = get_dataset(
        dataset_in,
        data_dir='/home/user/datasets/debias',
        dataset_split="train",
        transform_split="train",
)

# %%
indices_train_biased = train_dataset.attr[:,0] == train_dataset.attr[:,1]

indices_train_biased = indices_train_biased.nonzero().squeeze()

nums_train_biased = np.random.choice(indices_train_biased, int(train_samples - bias_ratio * train_samples) , replace=False)


indices_train_unbiased = train_dataset.attr[:,0] != train_dataset.attr[:,1]

indices_train_unbiased = indices_train_unbiased.nonzero().squeeze()

nums_train_unbiased = np.random.choice(indices_train_unbiased, int(bias_ratio * train_samples) , replace=False)

nums_train = np.concatenate((nums_train_biased, nums_train_unbiased))


nums_valid_unbiased = []

while len(nums_valid_unbiased) < 1000:
    i = np.random.randint(0, len(valid_dataset))
    if valid_dataset.attr[i,0] != valid_dataset.attr[i,1] and i not in nums_train:
        nums_valid_unbiased.append(i)

nums_valid_unbiased = np.array(nums_valid_unbiased)

train_dataset.attr = train_dataset.attr[nums_train]
train_dataset.data = train_dataset.data[nums_train]
train_dataset.__len__ = train_samples
train_dataset.query_attr = train_dataset.attr[:, torch.arange(2)]


valid_dataset.attr = valid_dataset.attr[nums_valid_unbiased]
valid_dataset.data = valid_dataset.data[nums_valid_unbiased]
valid_dataset.__len__ = 1000
valid_dataset.query_attr = valid_dataset.attr[:, torch.arange(2)]

print("[Size of the Dataset]["+str(len(train_dataset))+"]")
print("[Conflicting Samples in Training Data]["+str(len(train_dataset.attr[train_dataset.attr[:,0] != train_dataset.attr[:,1]]))+"]")
print("[Conflicting Samples in Validation Data]["+str(len(valid_dataset.attr[valid_dataset.attr[:,0] != valid_dataset.attr[:,1]]))+"]")

train_target_attr = train_dataset.attr[:, target_attr_idx]
train_bias_attr = train_dataset.attr[:, bias_attr_idx]

del indices_train_biased, indices_train_unbiased, nums_train_biased, nums_train_unbiased, nums_train, nums_valid_unbiased
# Out:
# [Size of the Dataset][2000]
# [Conflicting Samples in Training Data][40]
# [Conflicting Samples in Validation Data][1000]

# %%
attr_dims = []
attr_dims.append(torch.max(train_target_attr).item() + 1)
num_classes = attr_dims[0]

# %%
train_dataset = IdxDataset(train_dataset)
valid_dataset = IdxDataset(valid_dataset)    
test_dataset = IdxDataset(test_dataset)
 
train_loader = DataLoader(
        train_dataset,
        batch_size=250,
        shuffle=True,
        drop_last=True
    )

valid_loader = DataLoader(
        valid_dataset,
        batch_size=250,
        shuffle=False,
        drop_last=False
    )

test_loader = DataLoader(
        test_dataset,
        batch_size=250,
        shuffle=False,
        drop_last=False
    )
mem_loader = DataLoader(
        train_dataset,
        batch_size=100,
        shuffle=True,
        drop_last=True
)

# %%
try:
    model_d = dic_models[model_in+'_MW'](num_classes).to(device)
    model_b = dic_models[model_in](num_classes).to(device)
except:
    model_d = dic_models_2[model_in+'_MW'](num_classes).to(device)
    model_b = dic_models_2[model_in](num_classes).to(device)

# %%
if 'MNIST' in dataset_in:
    optimizer_b = torch.optim.Adam(model_b.parameters(),lr= 0.002, weight_decay=0.0)
    optimizer_d = torch.optim.Adam(model_d.parameters(),lr= 0.002, weight_decay=0.0)
    schedulerd = MultiStepLR(optimizer_d, milestones=[300], gamma=0.5)
    schedulerb = MultiStepLR(optimizer_b, milestones=[300], gamma=0.5)
else:
    optimizer_b = torch.optim.SGD(model_b.parameters(),lr= 0.1, weight_decay=5e-4, momentum = 0.9, nesterov = True)
    optimizer_d = torch.optim.SGD(model_d.parameters(),lr= 0.1, weight_decay=5e-4, momentum = 0.9, nesterov = True)
    schedulerd = MultiStepLR(optimizer_d, milestones=[150,225], gamma=0.1)
    schedulerb = MultiStepLR(optimizer_b, milestones=[150,225], gamma=0.1)

# %%
criterion = nn.CrossEntropyLoss(reduction='none')
bias_criterion = GeneralizedCELoss()

# %%
sample_loss_ema_b = EMA(torch.LongTensor(train_target_attr), alpha=0.7)
sample_loss_ema_d = EMA(torch.LongTensor(train_target_attr), alpha=0.7)

# %%
if 'CIFAR' in dataset_in:
    main_num_steps = 300
elif 'MNIST' in dataset_in:
    main_num_steps = 200

# %%
test_accuracy = -1.0
test_cheat = -1.0
test_accuracy_epoch = -1.0
valid_accuracy_best = -1.0

# %%
memory_loader_iter = iter(mem_loader)

# %%
from torch import maximum


for step in range(1, main_num_steps+1):

    for ix, (index,data,attr) in enumerate(train_loader):

        data = data.to(device)
        attr = attr.to(device)

        try:
            mem_index, mem_data, mem_attr = next(memory_loader_iter)
        except:
            memory_loader_iter = iter(mem_loader)
            mem_index, mem_data, mem_attr = next(memory_loader_iter)
        
        mem_data = mem_data.to(device)

        label = attr[:, target_attr_idx]
        bias_label = attr[:, bias_attr_idx]

        logit_b = model_b(data)
        logit_d, content_weights = model_d(data, mem_data, True)

        loss_b = criterion(logit_b, label).cpu().detach()
        loss_d = criterion(logit_d, label).cpu().detach()
        
        loss_per_sample_b = loss_b
        loss_per_sample_d = loss_d
        
        # EMA sample loss
        sample_loss_ema_b.update(loss_b, index)
        sample_loss_ema_d.update(loss_d, index)
        
        # class-wise normalize
        loss_b = sample_loss_ema_b.parameter[index].clone().detach()
        loss_d = sample_loss_ema_d.parameter[index].clone().detach()
        
        label_cpu = label.cpu()
        
        for c in range(num_classes):
            class_index = np.where(label_cpu == c)[0]
            max_loss_b = sample_loss_ema_b.max_loss(c)
            max_loss_d = sample_loss_ema_d.max_loss(c)
            loss_b[class_index] /= max_loss_b
            loss_d[class_index] /= max_loss_d
   
        # re-weighting based on loss value / generalized CE for biased model
        loss_weight = loss_b / (loss_b + loss_d + 1e-8)

        loss_b_update = bias_criterion(logit_b, label)

        loss_d_update = criterion(logit_d, label) * loss_weight.to(device)

        loss = loss_b_update.mean() + loss_d_update.mean()

        optimizer_b.zero_grad()
        optimizer_d.zero_grad()
        loss.backward()
        optimizer_b.step()
        optimizer_d.step()
    
    schedulerb.step()
    schedulerd.step()

    train_accuracy_epoch = evaluate_accuracy(model_d, train_loader, mem_loader)
    prev_valid_accuracy = valid_accuracy_best
    valid_accuracy_epoch = evaluate_accuracy(model_d, valid_loader, mem_loader)
    valid_accuracy_best = max(valid_accuracy_best, valid_accuracy_epoch)

    print("[Epoch "+str(step)+"][Train Accuracy", round(train_accuracy_epoch,4),"][Validation Accuracy",round(valid_accuracy_epoch,4),"]")

    test_accuracy_epoch = evaluate_accuracy(model_d, test_loader, mem_loader)

    test_cheat = max(test_cheat, test_accuracy_epoch)

    print("[Test Accuracy cheat][%.4f]"%test_cheat)

    if valid_accuracy_best > prev_valid_accuracy:
        test_accuracy = test_accuracy_epoch

    print('[Best Test Accuracy]', test_accuracy)


write_to_file('results_text/results_MW_LfF_'+dataset_in.split('-')[0]+'_'+str(train_samples)+'_'+str(bias_ratio)+'.txt','[Best Test Accuracy]'+str(test_accuracy)+"[Final Epoch Test Accuracy]"+str(test_accuracy_epoch)+ '[Best Cheat Test Accuracy]'+str(test_cheat))
# Out:
# [Epoch 1][Train Accuracy 9.65 ][Validation Accuracy 10.3 ]
# [Test Accuracy cheat][10.0900]
# [Best Test Accuracy] 10.090000182390213
# [Epoch 2][Train Accuracy 21.5 ][Validation Accuracy 12.4 ]
# [Test Accuracy cheat][11.2400]
# [Best Test Accuracy] 11.240000277757645
# [Epoch 3][Train Accuracy 57.4 ][Validation Accuracy 13.8 ]
# [Test Accuracy cheat][16.3500]
# [Best Test Accuracy] 16.349999606609344
# [Epoch 4][Train Accuracy 92.5 ][Validation Accuracy 22.3 ]
# [Test Accuracy cheat][23.5400]
# [Best Test Accuracy] 23.54000061750412
# [Epoch 5][Train Accuracy 97.25 ][Validation Accuracy 21.2 ]
# [Test Accuracy cheat][24.2500]
# [Best Test Accuracy] 23.54000061750412
# [Epoch 6][Train Accuracy 91.95 ][Validation Accuracy 19.2 ]
# [Test Accuracy cheat][24.2500]
# [Best Test Accuracy] 23.54000061750412
# [Epoch 7][Train Accuracy 96.75 ][Validation Accuracy 30.2 ]
# [Test Accuracy cheat][30.7400]
# [Best Test Accuracy] 30.739998817443848
# [Epoch 8][Train Accuracy 96.75 ][Validation Accuracy 33.8 ]
# [Test Accuracy cheat][32.7900]
# [Best Test Accuracy] 32.78999924659729
# [Epoch 9][Train Accuracy 93.9 ][Validation Accuracy 39.1 ]
# [Test Accuracy cheat][38.6100]
# [Best Test Accuracy] 38.60999941825867
# [Epoch 10][Train Accuracy 95.4 ][Validation Accuracy 34.9 ]
# [Test Accuracy cheat][38.6100]
# [Best Test Accuracy] 38.60999941825867
# [Epoch 11][Train Accuracy 95.05 ][Validation Accuracy 37.5 ]
# [Test Accuracy cheat][38.6100]
# [Best Test Accuracy] 38.60999941825867
# [Epoch 12][Train Accuracy 90.5 ][Validation Accuracy 46.0 ]
# [Test Accuracy cheat][43.5300]
# [Best Test Accuracy] 43.52999925613403
# [Epoch 13][Train Accuracy 81.9 ][Validation Accuracy 47.1 ]
# [Test Accuracy cheat][43.5300]
# [Best Test Accuracy] 43.45000088214874
# [Epoch 14][Train Accuracy 78.85 ][Validation Accuracy 49.0 ]
# [Test Accuracy cheat][46.8400]
# [Best Test Accuracy] 46.84000015258789
# [Epoch 15][Train Accuracy 85.8 ][Validation Accuracy 49.9 ]
# [Test Accuracy cheat][46.8400]
# [Best Test Accuracy] 46.25000059604645
# [Epoch 16][Train Accuracy 90.05 ][Validation Accuracy 53.4 ]
# [Test Accuracy cheat][48.9900]
# [Best Test Accuracy] 48.989999294281006
# [Epoch 17][Train Accuracy 86.9 ][Validation Accuracy 57.7 ]
# [Test Accuracy cheat][52.7800]
# [Best Test Accuracy] 52.78000235557556
# [Epoch 18][Train Accuracy 90.65 ][Validation Accuracy 53.7 ]
# [Test Accuracy cheat][52.7800]
# [Best Test Accuracy] 52.78000235557556
# [Epoch 19][Train Accuracy 63.9 ][Validation Accuracy 51.0 ]
# [Test Accuracy cheat][52.7800]
# [Best Test Accuracy] 52.78000235557556
# [Epoch 20][Train Accuracy 73.3 ][Validation Accuracy 52.0 ]
# [Test Accuracy cheat][52.7800]
# [Best Test Accuracy] 52.78000235557556
# [Epoch 21][Train Accuracy 72.2 ][Validation Accuracy 50.0 ]
# [Test Accuracy cheat][52.7800]
# [Best Test Accuracy] 52.78000235557556
# [Epoch 22][Train Accuracy 54.8 ][Validation Accuracy 44.8 ]
# [Test Accuracy cheat][52.7800]
# [Best Test Accuracy] 52.78000235557556
# [Epoch 23][Train Accuracy 70.3 ][Validation Accuracy 52.5 ]
# [Test Accuracy cheat][52.7800]
# [Best Test Accuracy] 52.78000235557556
# [Epoch 24][Train Accuracy 80.25 ][Validation Accuracy 60.8 ]
# [Test Accuracy cheat][52.8100]
# [Best Test Accuracy] 52.810001373291016
# [Epoch 25][Train Accuracy 82.75 ][Validation Accuracy 61.9 ]
# [Test Accuracy cheat][54.8900]
# [Best Test Accuracy] 54.89000082015991
# [Epoch 26][Train Accuracy 80.7 ][Validation Accuracy 60.0 ]
# [Test Accuracy cheat][54.8900]
# [Best Test Accuracy] 54.89000082015991
# [Epoch 27][Train Accuracy 62.5 ][Validation Accuracy 49.9 ]
# [Test Accuracy cheat][54.8900]
# [Best Test Accuracy] 54.89000082015991
# [Epoch 28][Train Accuracy 67.35 ][Validation Accuracy 52.4 ]
# [Test Accuracy cheat][54.8900]
# [Best Test Accuracy] 54.89000082015991
# [Epoch 29][Train Accuracy 83.95 ][Validation Accuracy 58.1 ]
# [Test Accuracy cheat][55.3000]
# [Best Test Accuracy] 54.89000082015991
# [Epoch 30][Train Accuracy 84.8 ][Validation Accuracy 58.2 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 54.89000082015991
# [Epoch 31][Train Accuracy 77.25 ][Validation Accuracy 38.8 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 54.89000082015991
# [Epoch 32][Train Accuracy 56.45 ][Validation Accuracy 40.2 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 54.89000082015991
# [Epoch 33][Train Accuracy 65.95 ][Validation Accuracy 41.8 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 54.89000082015991
# [Epoch 34][Train Accuracy 61.45 ][Validation Accuracy 51.3 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 54.89000082015991
# [Epoch 35][Train Accuracy 69.5 ][Validation Accuracy 58.6 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 54.89000082015991
# [Epoch 36][Train Accuracy 52.95 ][Validation Accuracy 39.2 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 54.89000082015991
# [Epoch 37][Train Accuracy 34.95 ][Validation Accuracy 37.7 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 54.89000082015991
# [Epoch 38][Train Accuracy 47.85 ][Validation Accuracy 43.6 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 54.89000082015991
# [Epoch 39][Train Accuracy 53.8 ][Validation Accuracy 40.7 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 54.89000082015991
# [Epoch 40][Train Accuracy 37.05 ][Validation Accuracy 36.7 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 54.89000082015991
# [Epoch 41][Train Accuracy 37.65 ][Validation Accuracy 40.2 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 54.89000082015991
# [Epoch 42][Train Accuracy 40.8 ][Validation Accuracy 42.4 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 54.89000082015991
# [Epoch 43][Train Accuracy 43.05 ][Validation Accuracy 40.6 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 54.89000082015991
# [Epoch 44][Train Accuracy 45.1 ][Validation Accuracy 46.1 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 54.89000082015991
# [Epoch 45][Train Accuracy 46.15 ][Validation Accuracy 45.3 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 54.89000082015991
# [Epoch 46][Train Accuracy 44.05 ][Validation Accuracy 45.4 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 54.89000082015991
# [Epoch 47][Train Accuracy 46.75 ][Validation Accuracy 43.5 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 54.89000082015991
# [Epoch 48][Train Accuracy 50.1 ][Validation Accuracy 44.0 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 54.89000082015991
# [Epoch 49][Train Accuracy 50.45 ][Validation Accuracy 44.4 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 54.89000082015991
# [Epoch 50][Train Accuracy 52.05 ][Validation Accuracy 44.2 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 54.89000082015991
# [Epoch 51][Train Accuracy 52.75 ][Validation Accuracy 44.2 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 54.89000082015991
# [Epoch 52][Train Accuracy 54.1 ][Validation Accuracy 46.3 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 54.89000082015991
# [Epoch 53][Train Accuracy 56.7 ][Validation Accuracy 46.7 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 54.89000082015991
# [Epoch
8 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 154][Train Accuracy 36.2 ][Validation Accuracy 32.8 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 155][Train Accuracy 37.3 ][Validation Accuracy 34.2 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 156][Train Accuracy 38.05 ][Validation Accuracy 35.8 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 157][Train Accuracy 38.7 ][Validation Accuracy 35.9 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 158][Train Accuracy 38.45 ][Validation Accuracy 35.3 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 159][Train Accuracy 37.8 ][Validation Accuracy 35.0 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 160][Train Accuracy 37.65 ][Validation Accuracy 35.1 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 161][Train Accuracy 37.05 ][Validation Accuracy 34.5 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 162][Train Accuracy 36.45 ][Validation Accuracy 34.3 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 163][Train Accuracy 39.8 ][Validation Accuracy 35.5 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 164][Train Accuracy 10.9 ][Validation Accuracy 13.3 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 165][Train Accuracy 16.35 ][Validation Accuracy 9.2 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 166][Train Accuracy 28.45 ][Validation Accuracy 9.3 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 167][Train Accuracy 29.25 ][Validation Accuracy 9.5 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 168][Train Accuracy 26.8 ][Validation Accuracy 9.8 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 169][Train Accuracy 31.2 ][Validation Accuracy 12.6 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 170][Train Accuracy 29.1 ][Validation Accuracy 8.9 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 171][Train Accuracy 29.45 ][Validation Accuracy 9.4 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 172][Train Accuracy 26.85 ][Validation Accuracy 9.5 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 173][Train Accuracy 27.1 ][Validation Accuracy 10.4 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 174][Train Accuracy 20.2 ][Validation Accuracy 12.4 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 175][Train Accuracy 20.2 ][Validation Accuracy 12.0 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 176][Train Accuracy 19.25 ][Validation Accuracy 12.6 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 177][Train Accuracy 18.85 ][Validation Accuracy 12.5 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 178][Train Accuracy 25.55 ][Validation Accuracy 11.0 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 179][Train Accuracy 20.5 ][Validation Accuracy 12.1 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 180][Train Accuracy 21.9 ][Validation Accuracy 12.8 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 181][Train Accuracy 21.45 ][Validation Accuracy 14.6 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 182][Train Accuracy 22.1 ][Validation Accuracy 12.7 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 183][Train Accuracy 23.6 ][Validation Accuracy 14.2 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 184][Train Accuracy 22.1 ][Validation Accuracy 13.9 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 185][Train Accuracy 20.3 ][Validation Accuracy 12.5 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 186][Train Accuracy 21.45 ][Validation Accuracy 12.9 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 187][Train Accuracy 24.55 ][Validation Accuracy 13.7 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 188][Train Accuracy 27.2 ][Validation Accuracy 11.8 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 189][Train Accuracy 25.5 ][Validation Accuracy 12.6 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 190][Train Accuracy 21.5 ][Validation Accuracy 11.7 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 191][Train Accuracy 25.95 ][Validation Accuracy 9.4 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 192][Train Accuracy 30.25 ][Validation Accuracy 12.0 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 193][Train Accuracy 20.45 ][Validation Accuracy 14.4 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 194][Train Accuracy 25.95 ][Validation Accuracy 13.0 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 195][Train Accuracy 37.1 ][Validation Accuracy 9.1 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 196][Train Accuracy 34.1 ][Validation Accuracy 11.2 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 197][Train Accuracy 30.75 ][Validation Accuracy 12.8 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 198][Train Accuracy 30.2 ][Validation Accuracy 11.8 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 199][Train Accuracy 30.8 ][Validation Accuracy 10.6 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
# [Epoch 200][Train Accuracy 24.7 ][Validation Accuracy 13.9 ]
# [Test Accuracy cheat][56.1200]
# [Best Test Accuracy] 55.549997091293335
