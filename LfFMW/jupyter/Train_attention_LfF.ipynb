# %%
import os
os.chdir('..')

# %%
from data.attr_dataset import AttributeDataset_bffhq
from module.loss import GeneralizedCELoss,EMA,MultiDimAverageMeter
from module.models import dic_models
from module.models2 import dic_models_2
from data.util import get_dataset, IdxDataset, ZippedDataset, get_dataset_bffhq
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from collections import Counter
from torch.utils.data import DataLoader, Dataset
from tqdm import tqdm
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import argparse
from torch.optim.lr_scheduler import MultiStepLR
import random
from numpy.random import RandomState

def set_seed(seed: int) -> RandomState:
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False # set to false for reproducibility, True to boost performance
    torch.manual_seed(seed)
    np.random.seed(seed)
    torch.cuda.manual_seed(seed)
    random.seed(seed)
    random_state = random.getstate()
    os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"
    return random_state


dataset_in = input("The dataset is: ")
model_in = input("The model is: ")
train_samples = int(input("The number of training samples is: "))
bias_ratio = float(input("The bias ratio is: "))
seed = int(input("The seed is: "))

set_seed(seed)

target_attr_idx = 0
bias_attr_idx = 1

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\ASUS\Desktop\LfFMW\jupyter\Train_attention_LfF.ipynb Cell 2 in <cell line: 34>()
#      <a href='vscode-notebook-cell:/c%3A/Users/ASUS/Desktop/LfFMW/jupyter/Train_attention_LfF.ipynb#W1sZmlsZQ%3D%3D?line=31'>32</a> dataset_in = input("The dataset is: ")
#      <a href='vscode-notebook-cell:/c%3A/Users/ASUS/Desktop/LfFMW/jupyter/Train_attention_LfF.ipynb#W1sZmlsZQ%3D%3D?line=32'>33</a> model_in = input("The model is: ")
# ---> <a href='vscode-notebook-cell:/c%3A/Users/ASUS/Desktop/LfFMW/jupyter/Train_attention_LfF.ipynb#W1sZmlsZQ%3D%3D?line=33'>34</a> train_samples = int(input("The number of training samples is: "))
#      <a href='vscode-notebook-cell:/c%3A/Users/ASUS/Desktop/LfFMW/jupyter/Train_attention_LfF.ipynb#W1sZmlsZQ%3D%3D?line=34'>35</a> bias_ratio = float(input("The bias ratio is: "))
#      <a href='vscode-notebook-cell:/c%3A/Users/ASUS/Desktop/LfFMW/jupyter/Train_attention_LfF.ipynb#W1sZmlsZQ%3D%3D?line=35'>36</a> seed = int(input("The seed is: "))
#
# ValueError: invalid literal for int() with base 10: ''

# %%
def write_to_file(filename, text):
    with open(filename, 'a') as f:
        f.write(text)
        f.write('\n')

# %%
def evaluate_accuracy(mw_model, test_loader, memory_loader):
  mw_model.eval()
  mw_correct = 0
  mem_iter = iter(memory_loader)
  with torch.no_grad():
    for _, data, target in test_loader:
        data = data.to(device)
        target = target[:,target_attr_idx]
        target = target.to(device)
        try:
            indexm,memory_input,_ = next(mem_iter)
        except:
            mem_iter = iter(memory_loader)
            indexm,memory_input,_ = next(mem_iter)
        memory_input = memory_input.to(device)

        mw_outputs = mw_model(data, memory_input)
        mw_pred = mw_outputs.data.max(1, keepdim=True)[1]

        mw_correct += mw_pred.eq(target.data.view_as(mw_pred)).sum().item()
  mw_accuracy = 100.*(torch.true_divide(mw_correct,len(test_loader.dataset))).item()
  mw_model.train()
  return mw_accuracy

# %%
train_dataset = get_dataset(
        dataset_in,
        data_dir='/home/user/datasets/debias',
        dataset_split="train",
        transform_split="train",
    )
test_dataset = get_dataset(
        dataset_in,
        data_dir='/home/user/datasets/debias',
        dataset_split="eval",
        transform_split="eval",
    )
valid_dataset = get_dataset(
        dataset_in,
        data_dir='/home/user/datasets/debias',
        dataset_split="train",
        transform_split="train",
)

# %%
indices_train_biased = train_dataset.attr[:,0] == train_dataset.attr[:,1]

indices_train_biased = indices_train_biased.nonzero().squeeze()

nums_train_biased = np.random.choice(indices_train_biased, int(train_samples - bias_ratio * train_samples) , replace=False)


indices_train_unbiased = train_dataset.attr[:,0] != train_dataset.attr[:,1]

indices_train_unbiased = indices_train_unbiased.nonzero().squeeze()

nums_train_unbiased = np.random.choice(indices_train_unbiased, int(bias_ratio * train_samples) , replace=False)

nums_train = np.concatenate((nums_train_biased, nums_train_unbiased))


nums_valid_unbiased = []

while len(nums_valid_unbiased) < 1000:
    i = np.random.randint(0, len(valid_dataset))
    if valid_dataset.attr[i,0] != valid_dataset.attr[i,1] and i not in nums_train:
        nums_valid_unbiased.append(i)

nums_valid_unbiased = np.array(nums_valid_unbiased)

train_dataset.attr = train_dataset.attr[nums_train]
train_dataset.data = train_dataset.data[nums_train]
train_dataset.__len__ = train_samples
train_dataset.query_attr = train_dataset.attr[:, torch.arange(2)]


valid_dataset.attr = valid_dataset.attr[nums_valid_unbiased]
valid_dataset.data = valid_dataset.data[nums_valid_unbiased]
valid_dataset.__len__ = 1000
valid_dataset.query_attr = valid_dataset.attr[:, torch.arange(2)]

print("[Size of the Dataset]["+str(len(train_dataset))+"]")
print("[Conflicting Samples in Training Data]["+str(len(train_dataset.attr[train_dataset.attr[:,0] != train_dataset.attr[:,1]]))+"]")
print("[Conflicting Samples in Validation Data]["+str(len(valid_dataset.attr[valid_dataset.attr[:,0] != valid_dataset.attr[:,1]]))+"]")

train_target_attr = train_dataset.attr[:, target_attr_idx]
train_bias_attr = train_dataset.attr[:, bias_attr_idx]

del indices_train_biased, indices_train_unbiased, nums_train_biased, nums_train_unbiased, nums_train, nums_valid_unbiased
# Out:
# [Size of the Dataset][2000]
# [Conflicting Samples in Training Data][40]
# [Conflicting Samples in Validation Data][1000]

# %%
attr_dims = []
attr_dims.append(torch.max(train_target_attr).item() + 1)
num_classes = attr_dims[0]

# %%
train_dataset = IdxDataset(train_dataset)
valid_dataset = IdxDataset(valid_dataset)    
test_dataset = IdxDataset(test_dataset)
 
train_loader = DataLoader(
        train_dataset,
        batch_size=250,
        shuffle=True,
        drop_last=True
    )

valid_loader = DataLoader(
        valid_dataset,
        batch_size=250,
        shuffle=False,
        drop_last=False
    )

test_loader = DataLoader(
        test_dataset,
        batch_size=250,
        shuffle=False,
        drop_last=False
    )
mem_loader = DataLoader(
        train_dataset,
        batch_size=100,
        shuffle=True,
        drop_last=True
)

# %%
try:
    model_d = dic_models[model_in+'_attention'](num_classes).to(device)
    model_b = dic_models[model_in](num_classes).to(device)
except:
    model_d = dic_models_2[model_in+'_attention'](num_classes).to(device)
    model_b = dic_models_2[model_in](num_classes).to(device)

# %%
if 'MNIST' in dataset_in:
    optimizer_b = torch.optim.Adam(model_b.parameters(),lr= 0.002, weight_decay=0.0)
    optimizer_d = torch.optim.Adam(model_d.parameters(),lr= 0.002, weight_decay=0.0)
    schedulerd = MultiStepLR(optimizer_d, milestones=[300], gamma=0.5)
    schedulerb = MultiStepLR(optimizer_b, milestones=[300], gamma=0.5)
else:
    optimizer_b = torch.optim.SGD(model_b.parameters(),lr= 0.1, weight_decay=5e-4, momentum = 0.9, nesterov = True)
    optimizer_d = torch.optim.SGD(model_d.parameters(),lr= 0.1, weight_decay=5e-4, momentum = 0.9, nesterov = True)
    schedulerd = MultiStepLR(optimizer_d, milestones=[150,225], gamma=0.1)
    schedulerb = MultiStepLR(optimizer_b, milestones=[150,225], gamma=0.1)

# %%
criterion = nn.CrossEntropyLoss(reduction='none')
bias_criterion = GeneralizedCELoss()

# %%
sample_loss_ema_b = EMA(torch.LongTensor(train_target_attr), alpha=0.7)
sample_loss_ema_d = EMA(torch.LongTensor(train_target_attr), alpha=0.7)

# %%
if 'CIFAR' in dataset_in:
    main_num_steps = 300
elif 'MNIST' in dataset_in:
    main_num_steps = 200

# %%
test_accuracy = -1.0
test_cheat = -1.0
test_accuracy_epoch = -1.0
valid_accuracy_best = -1.0

# %%
memory_loader_iter = iter(mem_loader)

# %%
from torch import maximum


for step in range(1, main_num_steps+1):

    for ix, (index,data,attr) in enumerate(train_loader):

        data = data.to(device)
        attr = attr.to(device)

        try:
            mem_index, mem_data, mem_attr = next(memory_loader_iter)
        except:
            memory_loader_iter = iter(mem_loader)
            mem_index, mem_data, mem_attr = next(memory_loader_iter)
        
        mem_data = mem_data.to(device)

        label = attr[:, target_attr_idx]
        bias_label = attr[:, bias_attr_idx]

        logit_b = model_b(data)
        logit_d, content_weights = model_d(data, mem_data, True)

        loss_b = criterion(logit_b, label).cpu().detach()
        loss_d = criterion(logit_d, label).cpu().detach()
        
        loss_per_sample_b = loss_b
        loss_per_sample_d = loss_d
        
        # EMA sample loss
        sample_loss_ema_b.update(loss_b, index)
        sample_loss_ema_d.update(loss_d, index)
        
        # class-wise normalize
        loss_b = sample_loss_ema_b.parameter[index].clone().detach()
        loss_d = sample_loss_ema_d.parameter[index].clone().detach()
        
        label_cpu = label.cpu()
        
        for c in range(num_classes):
            class_index = np.where(label_cpu == c)[0]
            max_loss_b = sample_loss_ema_b.max_loss(c)
            max_loss_d = sample_loss_ema_d.max_loss(c)
            loss_b[class_index] /= max_loss_b
            loss_d[class_index] /= max_loss_d
   
        # re-weighting based on loss value / generalized CE for biased model
        loss_weight = loss_b / (loss_b + loss_d + 1e-8)

        loss_b_update = bias_criterion(logit_b, label)

        loss_d_update = criterion(logit_d, label) * loss_weight.to(device)

        loss = loss_b_update.mean() + loss_d_update.mean()

        optimizer_b.zero_grad()
        optimizer_d.zero_grad()
        loss.backward()
        optimizer_b.step()
        optimizer_d.step()
    
    schedulerb.step()
    schedulerd.step()

    train_accuracy_epoch = evaluate_accuracy(model_d, train_loader, mem_loader)
    prev_valid_accuracy = valid_accuracy_best
    valid_accuracy_epoch = evaluate_accuracy(model_d, valid_loader, mem_loader)
    valid_accuracy_best = max(valid_accuracy_best, valid_accuracy_epoch)

    print("[Epoch "+str(step)+"][Train Accuracy", round(train_accuracy_epoch,4),"][Validation Accuracy",round(valid_accuracy_epoch,4),"]")

    test_accuracy_epoch = evaluate_accuracy(model_d, test_loader, mem_loader)

    test_cheat = max(test_cheat, test_accuracy_epoch)

    print("[Test Accuracy cheat][%.4f]"%test_cheat)

    if valid_accuracy_best > prev_valid_accuracy:
        test_accuracy = test_accuracy_epoch

    print('[Best Test Accuracy]', test_accuracy)


write_to_file('results_text/results_attention_LfF_'+dataset_in.split('-')[0]+'_'+str(train_samples)+'_'+str(bias_ratio)+'.txt','[Best Test Accuracy]'+str(test_accuracy)+"[Final Epoch Test Accuracy]"+str(test_accuracy_epoch)+ '[Best Cheat Test Accuracy]'+str(test_cheat))
# Out:
# [Epoch 1][Train Accuracy 9.2 ][Validation Accuracy 11.6 ]
# [Test Accuracy cheat][9.8800]
# [Best Test Accuracy] 9.880000352859497
# [Epoch 2][Train Accuracy 23.55 ][Validation Accuracy 12.9 ]
# [Test Accuracy cheat][12.5600]
# [Best Test Accuracy] 12.559999525547028

# [Best Test Accuracy] 54.180002212524414
# [Epoch 61][Train Accuracy 64.9 ][Validation Accuracy 60.3 ]
# [Test Accuracy cheat][54.1800]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 62][Train Accuracy 66.65 ][Validation Accuracy 57.2 ]
# [Test Accuracy cheat][54.1800]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 63][Train Accuracy 63.75 ][Validation Accuracy 59.2 ]
# [Test Accuracy cheat][54.1800]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 64][Train Accuracy 65.3 ][Validation Accuracy 62.7 ]
# [Test Accuracy cheat][54.8400]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 65][Train Accuracy 66.7 ][Validation Accuracy 63.5 ]
# [Test Accuracy cheat][54.8400]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 66][Train Accuracy 68.6 ][Validation Accuracy 63.1 ]
# [Test Accuracy cheat][54.8400]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 67][Train Accuracy 68.65 ][Validation Accuracy 63.3 ]
# [Test Accuracy cheat][55.5600]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 68][Train Accuracy 59.05 ][Validation Accuracy 47.3 ]
# [Test Accuracy cheat][55.5600]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 69][Train Accuracy 54.95 ][Validation Accuracy 50.3 ]
# [Test Accuracy cheat][55.5600]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 70][Train Accuracy 57.05 ][Validation Accuracy 54.7 ]
# [Test Accuracy cheat][55.5600]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 71][Train Accuracy 60.0 ][Validation Accuracy 52.5 ]
# [Test Accuracy cheat][55.5600]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 72][Train Accuracy 66.35 ][Validation Accuracy 48.0 ]
# [Test Accuracy cheat][55.5600]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 73][Train Accuracy 60.55 ][Validation Accuracy 50.4 ]
# [Test Accuracy cheat][55.5600]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 74][Train Accuracy 59.1 ][Validation Accuracy 50.2 ]
# [Test Accuracy cheat][55.5600]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 75][Train Accuracy 53.7 ][Validation Accuracy 53.0 ]
# [Test Accuracy cheat][55.5600]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 76][Train Accuracy 58.7 ][Validation Accuracy 58.8 ]
# [Test Accuracy cheat][55.5600]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 77][Train Accuracy 60.45 ][Validation Accuracy 60.8 ]
# [Test Accuracy cheat][55.5600]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 78][Train Accuracy 61.85 ][Validation Accuracy 60.0 ]
# [Test Accuracy cheat][55.5600]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 79][Train Accuracy 65.7 ][Validation Accuracy 58.9 ]
# [Test Accuracy cheat][55.5600]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 80][Train Accuracy 67.45 ][Validation Accuracy 60.7 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 81][Train Accuracy 68.6 ][Validation Accuracy 61.6 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 82][Train Accuracy 68.6 ][Validation Accuracy 60.9 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 83][Train Accuracy 69.7 ][Validation Accuracy 60.6 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 84][Train Accuracy 70.15 ][Validation Accuracy 59.9 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 85][Train Accuracy 71.4 ][Validation Accuracy 59.9 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 86][Train Accuracy 71.7 ][Validation Accuracy 59.3 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 87][Train Accuracy 72.25 ][Validation Accuracy 59.7 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 88][Train Accuracy 72.15 ][Validation Accuracy 59.8 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 89][Train Accuracy 73.55 ][Validation Accuracy 58.0 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 90][Train Accuracy 74.6 ][Validation Accuracy 59.3 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 91][Train Accuracy 75.95 ][Validation Accuracy 58.6 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 92][Train Accuracy 72.45 ][Validation Accuracy 57.8 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 93][Train Accuracy 68.65 ][Validation Accuracy 54.8 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 94][Train Accuracy 67.0 ][Validation Accuracy 55.1 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 95][Train Accuracy 68.65 ][Validation Accuracy 53.9 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch
]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 150][Train Accuracy 59.15 ][Validation Accuracy 45.9 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 151][Train Accuracy 60.2 ][Validation Accuracy 45.6 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 152][Train Accuracy 59.15 ][Validation Accuracy 40.7 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 153][Train Accuracy 53.2 ][Validation Accuracy 41.0 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 154][Train Accuracy 52.4 ][Validation Accuracy 43.0 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 155][Train Accuracy 55.9 ][Validation Accuracy 46.3 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 156][Train Accuracy 55.0 ][Validation Accuracy 45.5 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 157][Train Accuracy 55.85 ][Validation Accuracy 45.0 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 158][Train Accuracy 55.7 ][Validation Accuracy 45.1 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 159][Train Accuracy 56.15 ][Validation Accuracy 43.8 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 160][Train Accuracy 60.5 ][Validation Accuracy 44.1 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 161][Train Accuracy 60.1 ][Validation Accuracy 43.6 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 162][Train Accuracy 60.2 ][Validation Accuracy 44.0 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 163][Train Accuracy 61.35 ][Validation Accuracy 43.8 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 164][Train Accuracy 61.95 ][Validation Accuracy 45.6 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 165][Train Accuracy 59.25 ][Validation Accuracy 44.1 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 166][Train Accuracy 60.3 ][Validation Accuracy 44.9 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 167][Train Accuracy 59.25 ][Validation Accuracy 45.1 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 168][Train Accuracy 63.6 ][Validation Accuracy 46.7 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 169][Train Accuracy 66.25 ][Validation Accuracy 48.9 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 170][Train Accuracy 65.8 ][Validation Accuracy 48.6 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 171][Train Accuracy 64.75 ][Validation Accuracy 48.4 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 172][Train Accuracy 66.85 ][Validation Accuracy 48.4 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 173][Train Accuracy 66.85 ][Validation Accuracy 49.1 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 174][Train Accuracy 67.95 ][Validation Accuracy 49.2 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 175][Train Accuracy 68.5 ][Validation Accuracy 48.5 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 176][Train Accuracy 68.3 ][Validation Accuracy 49.2 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 177][Train Accuracy 68.9 ][Validation Accuracy 48.3 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 178][Train Accuracy 68.95 ][Validation Accuracy 47.8 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 179][Train Accuracy 68.65 ][Validation Accuracy 48.2 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 180][Train Accuracy 68.9 ][Validation Accuracy 47.7 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 181][Train Accuracy 69.15 ][Validation Accuracy 47.2 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 182][Train Accuracy 68.4 ][Validation Accuracy 47.5 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 183][Train Accuracy 67.4 ][Validation Accuracy 46.8 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 184][Train Accuracy 68.0 ][Validation Accuracy 47.4 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 185][Train Accuracy 68.95 ][Validation Accuracy 48.0 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 186][Train Accuracy 68.3 ][Validation Accuracy 47.6 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 187][Train Accuracy 68.5 ][Validation Accuracy 47.7 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 188][Train Accuracy 68.05 ][Validation Accuracy 47.7 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 189][Train Accuracy 68.05 ][Validation Accuracy 47.5 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 190][Train Accuracy 68.55 ][Validation Accuracy 47.4 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 191][Train Accuracy 68.15 ][Validation Accuracy 47.1 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 192][Train Accuracy 68.05 ][Validation Accuracy 47.6 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 193][Train Accuracy 68.55 ][Validation Accuracy 47.4 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 194][Train Accuracy 67.7 ][Validation Accuracy 47.5 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 195][Train Accuracy 67.75 ][Validation Accuracy 47.4 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 196][Train Accuracy 68.35 ][Validation Accuracy 47.3 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 197][Train Accuracy 67.55 ][Validation Accuracy 47.4 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 198][Train Accuracy 67.6 ][Validation Accuracy 47.5 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 199][Train Accuracy 68.25 ][Validation Accuracy 47.7 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
# [Epoch 200][Train Accuracy 67.8 ][Validation Accuracy 47.4 ]
# [Test Accuracy cheat][56.1700]
# [Best Test Accuracy] 54.180002212524414
